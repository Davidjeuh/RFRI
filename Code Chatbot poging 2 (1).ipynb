# %%
# !pip install nltk

# %%
import nltk
from nltk.chat.util import Chat, reflections

pairs = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today?"]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there"]
    ],
    [
        r"what is your name?",
        ["You can call me a chatbot"]
    ],
    [
        r"how are you?",
        ["I'm doing good", "I'm fine", "I'm good"]
    ],
    [
        r"sorry (.*)",
        ["Its alright", "Its OK, never mind"]
    ],
    [
        r"I am fine",
        ["Great to hear that"]
    ],
    [
        r"quit",
        ["Bye bye take care. It was nice talking to you :) "]
    ],
    [
        r"what's your hobby?",
        ["I love to chat with people"]
    ],
    [
        r"how old are you?",
        ["I am a computer program and don't have age"]
    ],
    [
        r"where are you from?",
        ["I am from the cloud"]
    ],
    [
        r"can you help me?",
        ["Sure, I will try my best to help you"]
    ],
    [
        r"what is your favourite (.*)?",
        ["I am a computer program, I don't have one"]
    ],
    [
        r"what is your opinion on (.*)?",
        ["I don't have a strong opinion on %1"]
    ],
    [
        r"what do you think about (.*)?",
        ["I don't have a strong opinion on %1"]
    ],
    [
        r"tell me a joke",
        ["Why did the tomato turn red? Because it saw the salad dressing!"]
    ],
    [
        r"what is the meaning of life?",
        ["That's a tough question. What do you think the meaning of life is?"]
    ],
    [
        r"what is your favorite color?",
        ["I don't have a favorite color since I'm a computer program"]
    ],
    [
        r"what is your favorite animal?",
        ["I don't have a favorite animal since I'm a computer program"]
    ],
    [
        r"what do you like to eat?",
        ["I don't eat since I'm a computer program"]
    ],
    [
        r"what is the weather like today?",
        ["I'm sorry, I don't have access to the internet to check the weather"]
    ],
    [
        r"do you have any siblings?",
        ["No, I'm an only child since I'm a computer program"]
    ],
    [
        r"what is your favorite book?",
        ["I don't have a favorite book since I'm a computer program"]
    ],
    [
        r"what is your favorite movie?",
        ["I don't have a favorite movie since I'm a computer program"]
    ],
    [
        r"what is your favorite song?",
        ["I don't have a favorite song since I'm a computer program"]
    ],
    [
        r"what is your favorite TV show?",
        ["I don't have a favorite TV show since I'm a computer program"]
    ],
    [
        r"what is your favorite hobby?",
        ["I don't have a favorite hobby since I'm a computer program"]
    ],
    [
        r"what is your favorite sport?",
        ["I don't have a favorite sport since I'm a computer program"]
    ],
    [
        r"what is your favorite thing to do?",
        ["I don't have a favorite thing to do since I'm a computer program"]
    ],
    [
        r"(.*)",
        ["Sorry, I didn't understand what you just said."]
    ]
]

chatbot = Chat(pairs, reflections)
chatbot.converse()
